# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# importing the data set

# %%
data = pd.read_csv("Churn.csv")
data.head()
# Out:
#   Customer ID  Gender  Senior Citizen Partner Dependents  tenure  \
# 0  7590-VHVEA  Female               0     Yes         No       1
# 1  7590-VHVEG  Female               0     Yes         No       1
# 2  5575-GNVDE    Male               0      No         No      34
# 3  3668-QPYBK    Male               0      No         No       2
# 4  7795-CFOCW    Male               0      No         No      45
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1            No  No phone service              DSL              No  ...
# 2           Yes                No              DSL             Yes  ...
# 3           Yes                No              DSL             Yes  ...
# 4            No  No phone service              DSL             Yes  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7044 entries, 0 to 7043
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer ID        7044 non-null   object
#  1   Gender             7044 non-null   object
#  2   Senior Citizen     7044 non-null   int64
#  3   Partner            7044 non-null   object
#  4   Dependents         7044 non-null   object
#  5   tenure             7044 non-null   int64
#  6   Phone Service      7044 non-null   object
#  7   Multiple Lines     7044 non-null   object
#  8   Internet Service   7044 non-null   object
#  9   Online Security    7044 non-null   object
#  10  Online Backup      7044 non-null   object
#  11  Device Protection  7044 non-null   object
#  12  Tech Support       7044 non-null   object
#  13  Streaming TV       7044 non-null   object
#  14  Streaming Movies   7044 non-null   object
#  15  Contract           7044 non-null   object
# ...

# %% [markdown]
# droping the customer ID column

# %%
data.drop(["Customer ID"], axis = 1, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7044 entries, 0 to 7043
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7044 non-null   object
#  1   Senior Citizen     7044 non-null   int64
#  2   Partner            7044 non-null   object
#  3   Dependents         7044 non-null   object
#  4   tenure             7044 non-null   int64
#  5   Phone Service      7044 non-null   object
#  6   Multiple Lines     7044 non-null   object
#  7   Internet Service   7044 non-null   object
#  8   Online Security    7044 non-null   object
#  9   Online Backup      7044 non-null   object
#  10  Device Protection  7044 non-null   object
#  11  Tech Support       7044 non-null   object
#  12  Streaming TV       7044 non-null   object
#  13  Streaming Movies   7044 non-null   object
#  14  Contract           7044 non-null   object
#  15  Paperless Billing  7044 non-null   object
# ...

# %% [markdown]
# removing duplicate rows

# %%
data = data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7021 entries, 0 to 7043
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7021 non-null   object
#  1   Senior Citizen     7021 non-null   int64
#  2   Partner            7021 non-null   object
#  3   Dependents         7021 non-null   object
#  4   tenure             7021 non-null   int64
#  5   Phone Service      7021 non-null   object
#  6   Multiple Lines     7021 non-null   object
#  7   Internet Service   7021 non-null   object
#  8   Online Security    7021 non-null   object
#  9   Online Backup      7021 non-null   object
#  10  Device Protection  7021 non-null   object
#  11  Tech Support       7021 non-null   object
#  12  Streaming TV       7021 non-null   object
#  13  Streaming Movies   7021 non-null   object
#  14  Contract           7021 non-null   object
#  15  Paperless Billing  7021 non-null   object
# ...

# %% [markdown]
# dealing with missing values

# %%
#checking for missing values
data.isna().sum()
# Out:
# Gender               0
# Senior Citizen       0
# Partner              0
# Dependents           0
# tenure               0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn                0
# dtype: int64

# %% [markdown]
# as we can see there are no missing values

# %%
data
# Out:
#       Gender  Senior Citizen Partner Dependents  tenure Phone Service  \
# 0     Female               0     Yes         No       1            No
# 2       Male               0      No         No      34           Yes
# 3       Male               0      No         No       2           Yes
# 4       Male               0      No         No      45            No
# 5     Female               0      No         No       2           Yes
# ...      ...             ...     ...        ...     ...           ...
# 7039    Male               0     Yes        Yes      24           Yes
# 7040  Female               0     Yes        Yes      72           Yes
# 7041  Female               0     Yes        Yes      11            No
# 7042    Male               1     Yes         No       4           Yes
# 7043    Male               0      No         No      66           Yes
#
#         Multiple Lines Internet Service Online Security Online Backup  \
# ...

# %%
data['Total Charges'] = pd.to_numeric(data['Total Charges'], errors='coerce')

# %%
data.isna().sum()
# Out:
# Gender                0
# Senior Citizen        0
# Partner               0
# Dependents            0
# tenure                0
# Phone Service         0
# Multiple Lines        0
# Internet Service      0
# Online Security       0
# Online Backup         0
# Device Protection     0
# Tech Support          0
# Streaming TV          0
# Streaming Movies      0
# Contract              0
# Paperless Billing     0
# Payment Method        0
# Monthly Charges       0
# Total Charges        11
# Churn                 0
# dtype: int64

# %%
data['Total Charges'].fillna(data['Total Charges'].mean(), inplace=True)
# Out:
# C:\Users\drsof\AppData\Local\Temp\ipykernel_26688\734064024.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Total Charges'].fillna(data['Total Charges'].mean(), inplace=True)

# %%
data.isna().sum()
# Out:
# Gender               0
# Senior Citizen       0
# Partner              0
# Dependents           0
# tenure               0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn                0
# dtype: int64

# %%
numerical_columns=["Monthly Charges","tenure","Total Charges","Senior Citizen"]
for c in numerical_columns:
    sns.boxplot(data[c])
    plt.show()

# %% [markdown]
# there are no outliers

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7021 entries, 0 to 7043
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7021 non-null   object
#  1   Senior Citizen     7021 non-null   int64
#  2   Partner            7021 non-null   object
#  3   Dependents         7021 non-null   object
#  4   tenure             7021 non-null   int64
#  5   Phone Service      7021 non-null   object
#  6   Multiple Lines     7021 non-null   object
#  7   Internet Service   7021 non-null   object
#  8   Online Security    7021 non-null   object
#  9   Online Backup      7021 non-null   object
#  10  Device Protection  7021 non-null   object
#  11  Tech Support       7021 non-null   object
#  12  Streaming TV       7021 non-null   object
#  13  Streaming Movies   7021 non-null   object
#  14  Contract           7021 non-null   object
#  15  Paperless Billing  7021 non-null   object
# ...

# %%
data['Senior Citizen'].value_counts()
# Out:
# Senior Citizen
# 0    5880
# 1    1141
# Name: count, dtype: int64

# %%
categorical_columns = data.select_dtypes(include=['object', 'category']).columns

# Remove 'churn' column from categorical_columns
categorical_columns = categorical_columns.drop('Churn')

print(categorical_columns)
# Out:
# Index(['Gender', 'Partner', 'Dependents', 'Phone Service', 'Multiple Lines',
#        'Internet Service', 'Online Security', 'Online Backup',
#        'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Contract', 'Paperless Billing', 'Payment Method'],
#       dtype='object')

# %%
data[numerical_columns]
# Out:
#       Monthly Charges  tenure  Total Charges  Senior Citizen
# 0               29.85       1          29.85               0
# 2               56.95      34        1889.50               0
# 3               53.85       2         108.15               0
# 4               42.30      45        1840.75               0
# 5               70.70       2         151.65               0
# ...               ...     ...            ...             ...
# 7039            84.80      24        1990.50               0
# 7040           103.20      72        7362.90               0
# 7041            29.60      11         346.45               0
# 7042            74.40       4         306.60               1
# 7043           105.65      66        6844.50               0
#
# [7021 rows x 4 columns]

# %% [markdown]
# Visualisation:(this part was done after  scaling the numerical var )

# %%
#distribution of churn 
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Churn')
plt.title('Distribution of Churn')
plt.xlabel('Churn')
plt.ylabel('Count')
plt.show()

# %%
# Distribution plot: Monthly Charges
plt.figure(figsize=(10, 6))
sns.histplot(data['Monthly Charges'], kde=True, color='blue')
plt.title('Distribution of Monthly Charges')
plt.xlabel('Monthly Charges')
plt.ylabel('Frequency')
plt.show()

# %%
# Pair plot: Relationships between numerical features
numerical_features = ['tenure', 'Monthly Charges', 'Total Charges']
sns.pairplot(data[numerical_features], diag_kind='kde')
plt.suptitle('Pair Plot of Numerical Features', y=1.02)
plt.show()

# %%
plt.figure(figsize=(12, 8))
correlation_matrix = data[numerical_columns].corr()

# Using a diverging palette for better visualization of positive and negative correlations
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
print(categorical_columns)
# Out:
# Index(['Gender', 'Partner', 'Dependents', 'Phone Service', 'Multiple Lines',
#        'Internet Service', 'Online Security', 'Online Backup',
#        'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Contract', 'Paperless Billing', 'Payment Method'],
#       dtype='object')

# %% [markdown]
# label encoding

# %%
from sklearn.preprocessing import LabelEncoder
import joblib

label_encoders = {}

# Function to encode categorical columns and store encoders
def label_encode_columns(df, categorical_columns):
    for col in categorical_columns:
        encoder = LabelEncoder()
        df[col] = encoder.fit_transform(df[col])
        label_encoders[col] = encoder
    return df

# Apply the encoding function
data = label_encode_columns(data, categorical_columns)

# %%
data
# Out:
#       Gender  Senior Citizen  Partner  Dependents  tenure  Phone Service  \
# 0          0               0        1           0       1              0
# 2          1               0        0           0      34              1
# 3          1               0        0           0       2              1
# 4          1               0        0           0      45              0
# 5          0               0        0           0       2              1
# ...      ...             ...      ...         ...     ...            ...
# 7039       1               0        1           1      24              1
# 7040       0               0        1           1      72              1
# 7041       0               0        1           1      11              0
# 7042       1               1        1           0       4              1
# 7043       1               0        0           0      66              1
#
#       Multiple Lines  Internet Service  Online Security  Online Backup  \
# ...

# %%
joblib.dump(label_encoders, 'label_encoders.pkl')
# Out:
# ['label_encoders.pkl']

# %%
from sklearn.preprocessing import LabelEncoder
encoder_churn = LabelEncoder()
data['Churn'] = encoder_churn.fit_transform(data['Churn'])

# %%
joblib.dump(encoder_churn, 'encoder_churn.pkl')
# Out:
# ['encoder_churn.pkl']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data[['Monthly Charges','tenure','Total Charges']] = scaler.fit_transform(data[['Monthly Charges','tenure','Total Charges']])

# %%
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %% [markdown]
# spliting the dataset

# %%
X = data.drop(["Churn"],axis=1)
y = data["Churn"]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=4)

# %% [markdown]
# Models training: logitistic,decision tree and Random forest

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# Initialize models
logistic_model = LogisticRegression(penalty="l2",C=10)
decision_tree_model = DecisionTreeClassifier()
random_forest_model = RandomForestClassifier(n_estimators=100)

# Train models
logistic_model.fit(X_train, y_train)
decision_tree_model.fit(X_train, y_train)
random_forest_model.fit(X_train, y_train)

# Predict on training data
y_train_pred_logistic = logistic_model.predict(X_train)
y_train_pred_tree = decision_tree_model.predict(X_train)
y_train_pred_forest = random_forest_model.predict(X_train)

# Predict on test data
y_test_pred_logistic = logistic_model.predict(X_test)
y_test_pred_tree = decision_tree_model.predict(X_test)
y_test_pred_forest = random_forest_model.predict(X_test)

# %%
# Function to print evaluation metrics
def print_metrics(y_true, y_pred, dataset_type):
    print(f"Metrics for {dataset_type} dataset:")
    print(f"Accuracy: {accuracy_score(y_true, y_pred):.4f}")
    print(f"Precision: {precision_score(y_true, y_pred):.4f}")
    print(f"Recall: {recall_score(y_true, y_pred):.4f}")
    print(f"F1 Score: {f1_score(y_true, y_pred):.4f}")
    print(confusion_matrix(y_true, y_pred))
    print("-" * 30)

# Evaluate models on training data
print("Logistic Regression")
print_metrics(y_train, y_train_pred_logistic, "Training")
print_metrics(y_test, y_test_pred_logistic, "Test")

print("Decision Tree")
print_metrics(y_train, y_train_pred_tree, "Training")
print_metrics(y_test, y_test_pred_tree, "Test")

print("Random Forest")
print_metrics(y_train, y_train_pred_forest, "Training")
print_metrics(y_test, y_test_pred_forest, "Test")
# Out:
# Logistic Regression
# Metrics for Training dataset:
# Accuracy: 0.8048
# Precision: 0.6573
# Recall: 0.5573
# F1 Score: 0.6032
# [[3226  380]
#  [ 579  729]]
# ------------------------------
# Metrics for Test dataset:
# Accuracy: 0.7950
# Precision: 0.6247
# Recall: 0.5337
# F1 Score: 0.5756
# [[1382  176]
#  [ 256  293]]
# ------------------------------
# Decision Tree
# Metrics for Training dataset:
# Accuracy: 0.9984
# Precision: 1.0000
# Recall: 0.9939
# F1 Score: 0.9969
# [[3606    0]
#  [   8 1300]]
# ------------------------------
# Metrics for Test dataset:
# Accuracy: 0.7347
# Precision: 0.4916
# Recall: 0.5301
# F1 Score: 0.5101
# [[1257  301]
#  [ 258  291]]
# ------------------------------
# Random Forest
# Metrics for Training dataset:
# Accuracy: 0.9984
# Precision: 0.9954
# Recall: 0.9985
# F1 Score: 0.9969
# [[3600    6]
#  [   2 1306]]
# ------------------------------
# Metrics for Test dataset:
# Accuracy: 0.7850
# Precision: 0.6116
# Recall: 0.4791
# ...

# %% [markdown]
# the logistics regression performs best in this situation because the difference between the test and training is negligeable:
# Accuracy training: 0.8048
# Accuracy test: 0.7950
#
# the random forest has the second best performance with:
# Accuracy training: 0.9984
# Accuracy tets: 0.7850
#
# for the decision tree we notice an overfitting with:
# Accuracy training: 0.9984
# Accuracy test: 0.7347

# %% [markdown]
# the best model to deploy is the logistics regression because the training and test accuracy are close to each other

# %%
joblib.dump(logistic_model, 'logistic_model.pkl')
# Out:
# ['logistic_model.pkl']
